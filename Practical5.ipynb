# %% [markdown]
# <a href="https://colab.research.google.com/github/mariawandhare/data_science_66/blob/main/Practical5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv("cars.csv")
print(data.head())
# Out:
#     mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year     brand
# 0  14.0           8          350  165       4209           12   1972       US.
# 1  31.9           4           89   71       1925           14   1980   Europe.
# 2  17.0           8          302  140       3449           11   1971       US.
# 3  15.0           8          400  150       3761           10   1971       US.
# 4  30.5           4           98   63       2051           17   1978       US.

# %%
import pandas as pd
import numpy as np

# Load dataset
data = pd.read_csv("cars.csv")

# Clean column names
data.columns = data.columns.str.strip().str.lower()

# Convert numeric columns properly
numeric_cols = ["mpg", "cylinders", "cubicinches", "hp", "weightlbs", "time-to-60", "year"]
for col in numeric_cols:
    data[col] = pd.to_numeric(data[col], errors='coerce')

# Remove rows with missing values
data.dropna(inplace=True)

print("First 5 rows of dataset:\n")
print(data.head())

# ----------------------------
# Filtering Data
# ----------------------------
# Cars with mileage greater than 25 mpg
filtered_data = data[data["mpg"] > 25]

print("\nFiltered Data (Cars with MPG > 25):\n")
print(filtered_data.head())

# ----------------------------
# Grouping & Aggregation
# ----------------------------
grouped_data = data.groupby("brand").agg({
    "mpg": ["mean", "min", "max"],
    "hp": ["mean", "min", "max"],
    "weightlbs": ["mean", "min", "max"],
    "brand": "count"
})

print("\nGrouped & Aggregated Statistics (By Brand):\n")
print(grouped_data)

# ----------------------------
# Overall Statistics
# ----------------------------
print("\nOverall Statistical Summary:\n")
print(data.describe())
# Out:
# First 5 rows of dataset:
#
#     mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year     brand
# 0  14.0          8        350.0  165     4209.0          12  1972       US.
# 1  31.9          4         89.0   71     1925.0          14  1980   Europe.
# 2  17.0          8        302.0  140     3449.0          11  1971       US.
# 3  15.0          8        400.0  150     3761.0          10  1971       US.
# 4  30.5          4         98.0   63     2051.0          17  1978       US.
#
# Filtered Data (Cars with MPG > 25):
#
#      mpg  cylinders  cubicinches  hp  weightlbs  time-to-60  year     brand
# 1   31.9          4         89.0  71     1925.0          14  1980   Europe.
# 4   30.5          4         98.0  63     2051.0          17  1978       US.
# 8   25.4          5        183.0  77     3530.0          20  1980   Europe.
# 9   37.7          4         89.0  62     2050.0          17  1982    Japan.
# ...
